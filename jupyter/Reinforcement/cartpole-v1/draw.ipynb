# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
def func(x):
    pos = x
    nega = 1.0 - x
    return -np.log(pos+1e-5) - np.log(nega+1e-5)

# %%
X = np.arange(0, 1, 1e-5)
Y = list(map(func, X))

# %%
plt.plot(X,Y)
